# %% [markdown]
# # Longest Common Prefix
# Write a function to find the longest common prefix string amongst an array of strings.
#
# If there is no common prefix, return an empty string "".
#
#
# Example 1:
#
# Input: strs = ["flower","flow","flight"]
# Output: "fl"
#
# Example 2:
#
# Input: strs = ["dog","racecar","car"]
# Output: ""
# Explanation: There is no common prefix among the input strings.
#
#
# Constraints:
#
# 1 <= strs.length <= 200
# 0 <= strs[i].length <= 200
# strs[i] consists of only lowercase English letters.

# %%
tests = [
	{
		"strs": ["flower","flow","flight"],
		"expectedOutput": "fl"
	},
	{
		"strs": ["dog","racecar","car"],
		"expectedOutput": ""
	},
]

# %% [markdown]
# # Solution #1
# Description

# %%
def longest_common_prefix(strs):
    """
    :type strs: List[str]
    :rtype: str
    """
    # Compare Largest Common Prefix substring through every string and use always the one with less common chars
    # Compare 1st and 2nd strings and find a Common Prefix. It can have many, find the largest one. Find a common substring. Sliding Windows or 
      # If we use sliding windows we would need to know the max
    # Edge cases: When no strings are passed down
    if len(strs) == 0:
      return 0

# %%
for test in tests:
    output = longest_common_prefix(test["strs"])
    print('output',output)
    print('>', output == test["expectedOutput"])
